# %%
from scipy.io.arff import loadarff
import numpy as np
import pandas as pd
print('Libraries Loaded')
# Out:
# Libraries Loaded

# %%
filepath = 'CICDataSet-TOR/Scenario-A/TimeBasedFeatures-15s-TOR-NonTOR.arff'
raw_data = loadarff(filepath)

# %%
raw_data
# Out:
# (array([( 9368711., 1.6000000e+01, 4.0000000e+00, 1.564818e+06, 1.549373e+06,  190205.28571429,  203290.45652174,  389822.39191658,  370323.71975366, 10.35361215,  4802.68843814,  4., 1523088.,  97590.73958333,  267600.19844335,  1.871488e+06, 1983656.33333333,  2.195089e+06,  183219.69791437,  1.234883e+06, 1420565.,  1.523088e+06,  161096.53927537, b'NONTOR'),
#         ( 7340238., 1.8000000e+01, 4.0000000e+00, 1.567554e+06, 1.527893e+06,  165686.97727273,  186914.84615385,  317267.5487422 ,  304370.65130139, 11.58000599,  4340.18624464,  4., 1517774.,  87383.78571429,  221462.86202794,  1.491627e+06, 3572433.        ,  5.653239e+06, 2942704.06586714,  1.131498e+06, 1324636.,  1.517774e+06,  273138.37900778, b'NONTOR'),
#         ( 4644225., 2.9000000e+01, 1.5000000e+01, 1.270547e+06, 1.079974e+06,  165865.17857143,  195302.13043478,  329473.12626076,  300492.58822667, 11.41202246,  4161.51241596, 15., 1079974.,  89312.01923077,  217475.42524643,  1.758922e+06, 1758922.        ,  1.758922e+06,       0.        ,  1.079974e+06, 1079974.,  1.079974e+06,       0.        , b'NONTOR'),
#         ...,
#         (14660517., 1.4660517e+07, 1.4618019e+07, 3.330000e+02, 6.130000e+02, 7663754.        , 7663955.        , 1628946.33333333, 1827252.375     ,  1.29599795,   455.30454349, 36., 7663347., 814473.16666667, 2116240.74563766,  6.381394e+06, 7023854.5       ,  7.666315e+06,  908576.35238845,  5.314745e+06, 6489046.,  7.663347e+06, 1660712.40050799, b'TOR'),
#         (14832948., 1.4832905e+07, 1.4792242e+07, 7.000000e+00, 1.200000e+01,  788476.        ,  825018.        ,   43244.62099125,   43506.59411765, 46.18097495, 25954.17984341,  0.,  788476.,  21685.59649123,   69150.61424039, -1.000000e+00,       0.        , -1.000000e+00,       0.        , -1.000000e+00,       0., -1.000000e+00,       0.        , b'TOR'),
#         (14633355., 1.4633355e+07, 1.4632000e+07, 6.000000e+00, 3.400000e+01, 1707112.        , 1707109.        ,   41809.58571429,   47661.23778502, 45.03410189, 26701.66889275,  5., 1707073.,  22239.14133739,   85961.49580304,  2.006278e+06, 2006278.        ,  2.006278e+06,       0.        ,  1.707073e+06, 1707073.,  1.707073e+06,       0.        , b'TOR')],
#        dtype=[('duration', '<f8'), ('total_fiat', '<f8'), ('total_biat', '<f8'), ('min_fiat', '<f8'), ('min_biat', '<f8'), ('max_fiat', '<f8'), ('max_biat', '<f8'), ('mean_fiat', '<f8'), ('mean_biat', '<f8'), ('flowPktsPerSecond', '<f8'), ('flowBytesPerSecond', '<f8'), ('min_flowiat', '<f8'), ('max_flowiat', '<f8'), ('mean_flowiat', '<f8'), ('std_flowiat', '<f8'), ('min_active', '<f8'), ('mean_active', '<f8'), ('max_active', '<f8'), ('std_active', '<f8'), ('min_idle', '<f8'), ('mean_idle', '<f8'), ('max_idle', '<f8'), ('std_idle', '<f8'), ('class1', 'S6')]),
#  Dataset: <ISCXFlowMeter-generated-flows>,,,,,,,,,,,,,,,,,,,,,,,
#  	duration's type is numeric
#  	total_fiat's type is numeric
#  	total_biat's type is numeric
#  	min_fiat's type is numeric
#  	min_biat's type is numeric
#  	max_fiat's type is numeric
#  	max_biat's type is numeric
#  	mean_fiat's type is numeric
#  	mean_biat's type is numeric
#  	flowPktsPerSecond's type is numeric
#  	flowBytesPerSecond's type is numeric
#  	min_flowiat's type is numeric
#  	max_flowiat's type is numeric
#  	mean_flowiat's type is numeric
#  	std_flowiat's type is numeric
#  	min_active's type is numeric
#  	mean_active's type is numeric
#  	max_active's type is numeric
#  	std_active's type is numeric
#  	min_idle's type is numeric
#  	mean_idle's type is numeric
#  	max_idle's type is numeric
#  	std_idle's type is numeric
#  	class1's type is nominal, range is ('TOR', 'NONTOR'))

# %%
df_data = pd.DataFrame(raw_data[0])

# %%
df_data
# Out:
#          duration  total_fiat  total_biat   min_fiat   min_biat      max_fiat  \
# 0       9368711.0        16.0         4.0  1564818.0  1549373.0  1.902053e+05
# 1       7340238.0        18.0         4.0  1567554.0  1527893.0  1.656870e+05
# 2       4644225.0        29.0        15.0  1270547.0  1079974.0  1.658652e+05
# 3       4978735.0        19.0         8.0  2492050.0  2457286.0  2.395432e+05
# 4      11838189.0        19.0        10.0  3094089.0  3093543.0  2.437665e+05
# ...           ...         ...         ...        ...        ...           ...
# 22067  13932812.0  13932390.0  13932812.0       93.0      244.0  8.119562e+06
# 22068  14999975.0  14999975.0  14961989.0        0.0        7.0  1.624147e+06
# 22069  14660517.0  14660517.0  14618019.0      333.0      613.0  7.663754e+06
# 22070  14832948.0  14832905.0  14792242.0        7.0       12.0  7.884760e+05
# 22071  14633355.0  14633355.0  14632000.0        6.0       34.0  1.707112e+06
#
#            max_biat     mean_fiat     mean_biat  flowPktsPerSecond  ...  \
# 0      2.032905e+05  3.898224e+05  3.703237e+05          10.353612  ...
# 1      1.869148e+05  3.172675e+05  3.043707e+05          11.580006  ...
# 2      1.953021e+05  3.294731e+05  3.004926e+05          11.412022  ...
# 3      2.765964e+05  6.124353e+05  6.283396e+05           8.034169  ...
# 4      2.959547e+05  5.997218e+05  6.256327e+05           7.602514  ...
# ...             ...           ...           ...                ...  ...
# 22067  8.081967e+06  3.240091e+05  2.843431e+05           6.746664  ...
# 22068  1.624060e+06  2.103783e+04  2.939487e+04          81.600136  ...
# 22069  7.663955e+06  1.628946e+06  1.827252e+06           1.295998  ...
# 22070  8.250180e+05  4.324462e+04  4.350659e+04          46.180975  ...
# 22071  1.707109e+06  4.180959e+04  4.766124e+04          45.034102  ...
#
#         std_flowiat  min_active   mean_active  max_active    std_active  \
# 0      2.676002e+05   1871488.0  1.983656e+06   2195089.0  1.832197e+05
# 1      2.214629e+05   1491627.0  3.572433e+06   5653239.0  2.942704e+06
# 2      2.174754e+05   1758922.0  1.758922e+06   1758922.0  0.000000e+00
# 3      4.369597e+05   1710925.0  2.382905e+06   3054885.0  9.503232e+05
# 4      4.361296e+05   1747431.0  2.400446e+06   3240696.0  6.232744e+05
# ...             ...         ...           ...         ...           ...
# 22067  8.490494e+05   1506874.0  6.966222e+06  12425570.0  7.720684e+06
# 22068  7.020772e+04   3249302.0  3.525820e+06   3802338.0  3.910555e+05
# 22069  2.116241e+06   6381394.0  7.023854e+06   7666315.0  9.085764e+05
# 22070  6.915061e+04        -1.0  0.000000e+00        -1.0  0.000000e+00
# 22071  8.596150e+04   2006278.0  2.006278e+06   2006278.0  0.000000e+00
#
#         min_idle  mean_idle   max_idle      std_idle     class1
# 0      1234883.0  1420565.0  1523088.0  1.610965e+05  b'NONTOR'
# 1      1131498.0  1324636.0  1517774.0  2.731384e+05  b'NONTOR'
# 2      1079974.0  1079974.0  1079974.0  0.000000e+00  b'NONTOR'
# 3      1346073.0  1894031.5  2441990.0  7.749303e+05  b'NONTOR'
# 4      1394455.0  1983227.0  3042717.0  7.259878e+05  b'NONTOR'
# ...          ...        ...        ...           ...        ...
# 22067  1469335.0  4775651.0  8081967.0  4.675837e+06     b'TOR'
# 22068  1288308.0  1456115.5  1623923.0  2.373156e+05     b'TOR'
# 22069  5314745.0  6489046.0  7663347.0  1.660712e+06     b'TOR'
# 22070       -1.0        0.0       -1.0  0.000000e+00     b'TOR'
# 22071  1707073.0  1707073.0  1707073.0  0.000000e+00     b'TOR'
#
# [22072 rows x 24 columns]

# %%
df_data['class1'].value_counts()
# Out:
# b'NONTOR'    18758
# b'TOR'        3314
# Name: class1, dtype: int64
